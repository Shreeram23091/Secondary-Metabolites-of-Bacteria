# %%
# !pip install Bio
# Out:
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...

# %%
from Bio.Entrez import efetch
from Bio import Entrez
import pandas as pd
df = pd.read_csv("Task1_pubmed_secondary_metabolites_Bacteria") #this file is on zip folder
def print_abstract(pmid):
    try:
        handle = efetch(db='pubmed', id=pmid, retmode='text', rettype='abstract')
        abstract = handle.read()
        df.loc[df['PMID'] == pmid, 'ABSTRACT'] = abstract
        # print(abstract)
    except Exception as e:
        print(f"Error fetching abstract for PMID {pmid}: {str(e)}")


df.head()
# Out:
#        PMID                                              Title  \
# 0  33817931                      Astrobiology of life on Earth
# 1  30381012  Biochemical and thermodynamic analyses of ener...
# 2   8688447    Respiratory chains of archaea and extremophiles
# 3  35010636  Extremely Acidic Eukaryotic (Micro) Organisms:...
# 4  31470685                      Worms' Antimicrobial Peptides
#
#                                              Authors  \
# 0  Hallsworth JE, Mancinelli RL, Conley CA, Dalla...
# 1                                           Wakai S.
# 2   Schäfer G, Purschke WG, Gleissner M, Schmidt CL.
# 3  Luís AT, Córdoba F, Antunes C, Loayza-Muro R, ...
# 4  Bruno R, Maresca M, Canaan S, Cavalier JF, Mab...
#
#                                             Citation   First Author  \
# 0  Environ Microbiol. 2021 Jul;23(7):3335-3344. d...  Hallsworth JE
# 1  Biosci Biotechnol Biochem. 2019 Jan;83(1):49-6...        Wakai S
# ...

# %%
pmid = list(df['PMID'])
len(pmid)
# Out:
# 183

# %%
for id in pmid:
  print_abstract(id)
# Out:
# /usr/local/lib/python3.10/dist-packages/Bio/Entrez/__init__.py:723: UserWarning:
#
#             Email address is not specified.
#
#
#
#             To make use of NCBI's E-utilities, NCBI requires you to specify your
#
#             email address with each request.  As an example, if your email address
#
#             is A.N.Other@example.com, you can specify it as follows:
#
#                from Bio import Entrez
#
#                Entrez.email = 'A.N.Other@example.com'
#
#             In case of excessive usage of the E-utilities, NCBI will attempt to contact
#
#             a user at the email address provided before blocking access to the
#
#             E-utilities.
#
#   warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/Bio/Entrez/__init__.py:723: UserWarning:
#
#             Email address is not specified.
#
#
#
#             To make use of NCBI's E-utilities, NCBI requires you to specify your
#
# ...

# %%
df.to_csv("VD_pubmedList_21.csv",index=False)
